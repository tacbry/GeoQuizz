# %% [markdown]
# # **Plan de l'application**

# %% [markdown]
# ## Jeu de quizz géographie

# %% [markdown]
# - Quizz sur les capitales
# - Quizz sur les drapeaux
# - Leaderboard
# - (possibilité de différente manière d'interroger)
# - mode marathon ou mode precision (%age de réussite sur une selection proposée de 15 , 20 , 25,... qauestion)
# - mode capitale, mode drapeau, mode mixte
# - Appliquer une tolerance orthographique

# %% [markdown]
# ### engine.py

# %% [markdown]
# - boucle de jeu
# - charger les données (data des pays, score)
# - générer une question capitale
# - generer une question drapeau
# - sauvegarder score
# - afficher score
# -

# %% [markdown]
# ### test_engine.py

# %% [markdown]
# - tester si erreur si pas de chargement de fichier
# -

# %% [markdown]
# ### ui.py

# %% [markdown]
# Utilisation de kivy et des kivy files => Permet une meilleure gestion du multiscreen que tkinter
#
# - ecran menu
# - ecran jeu
# - afficher quizz capitales
#     - Afficher nom du pays avec son drapeau et trouver la capitale
#         - niv 1 : choix multiples (avec boutons)
#         - niv 2 : afficher la premiere lettre
#         - niv 3 : aucun indice
# - Afficher quizz drapeau :
#     - Afficher le drapeau
#         - niv 1 : choix multiples (avec boutons)
#         - niv 2 : afficher la premiere lettre
#         - niv 3 : aucun indice

# %% [markdown]
# ## Packages utilisés :
#
# - Typing (pour List)
# - cPickle (lecture/ecriture de fichier)
# - pathlib
# -

# %% [markdown]
# ## Utilisation de l'IA :

# %% [markdown]
# https://copilot.microsoft.com/conversations/join/B47fm8Z7b9HCEsdZdE99n (historique de la discussion)
#
# La consigne donnée à l'IA est d'accompagner la réflexion et non générer le code.
#
# - Propositions d'idées de projet
# - Questions techniques (format des fichiers en stockage, évaluer meilleur choix entre différentes approches)
# - Génération logo

# %% [markdown]
# ## Autres sources :
#
# - https://docs.python.org/
# - https://tutorialreference.com/python
# - https://koor.fr/Python/Tutoriel_Tkinter/
# - https://kivy.org/doc/stable/
# - Reddit
# - "Programmation Python - Concept et optimisation - 2e édition" - Tarek Ziadé

# %% [markdown]
# You have multiple transitions available by default, such as:
#
#     NoTransition - switches screens instantly with no animation
#
#     SlideTransition - slide the screen in/out, from any direction
#
#     CardTransition - new screen slides on the previous or the old one slides off the new one depending on the mode
#
#     SwapTransition - implementation of the iOS swap transition
#
#     FadeTransition - shader to fade the screen in/out
#
#     WipeTransition - shader to wipe the screens from right to left
#
#     FallOutTransition - shader where the old screen ‘falls’ and becomes transparent, revealing the new one behind it.
#
#     RiseInTransition - shader where the new screen rises from the screen centre while fading from transparent to opaque.
#
# You can easily switch transitions by changing the ScreenManager.transition property

# %% [markdown]
# notes :
#
# Passage de variable :
# de manière générale
# - on crée au préalable les variable dans app
# -il faut utiliser le on pre enter
#     - via un bouton
#         - creer la fonction qui sera dans on press
#         -
#
#         pour afficher dans le label sur l'ecran suivant on charge label.text = self.app.variable_a_passer
#     - via un textinput
#         -
# si un label doit charger une variable, il faut créer le label dans init et assigner la variable dans on pre enter
